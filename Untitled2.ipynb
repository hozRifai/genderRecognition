# %%
# Beat tracking example
from __future__ import print_function
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import python_speech_features as mfcc
from python_speech_features import mfcc
from python_speech_features import logfbank
import scipy.io.wavfile as wav

# %%
# 1. Get the file path to the included audio example
filename = "Recording.wav"

# 2. Load the audio as a waveform `y`
#    Store the sampling rate as `sr`
sr, y = librosa.load(filename)
mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
mfcc_delta = librosa.feature.delta(mfcc)
print(mfcc_delta)

# def get_MFCC(filename):
#     features = mfcc.mfcc(filename, rate, 0.025, 0.01, 13, appendEnergy = False)
#     features = preprocessing.scale(features)
#     return features
    
# print(get_MFCC(filename))

# mfcc_feat = mfcc(sig,rate)
(rate,sig) = wav.read(filename)
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)

#print(fbank_feat[:2, :26 ]) #the number of filters in the filterbank, default 26.
# Out:
# ---------------------------------------------------------------------------
# ParameterError                            Traceback (most recent call last)
# <ipython-input-29-62051e3137b1> in <module>
#       5 #    Store the sampling rate as `sr`
#       6 sr, y = librosa.load(filename)
# ----> 7 mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
#       8 mfcc_delta = librosa.feature.delta(mfcc)
#       9 print(mfcc_delta)
#
# c:\users\hozrifai\desktop\junior\venv\lib\site-packages\librosa\feature\spectral.py in mfcc(y, sr, S, n_mfcc, dct_type, norm, **kwargs)
#    1440
#    1441     if S is None:
# -> 1442         S = power_to_db(melspectrogram(y=y, sr=sr, **kwargs))
#    1443
#    1444     return scipy.fftpack.dct(S, axis=0, type=dct_type, norm=norm)[:n_mfcc]
#
# c:\users\hozrifai\desktop\junior\venv\lib\site-packages\librosa\feature\spectral.py in melspectrogram(y, sr, S, n_fft, hop_length, power, **kwargs)
#    1529
#    1530     S, n_fft = _spectrogram(y=y, S=S, n_fft=n_fft, hop_length=hop_length,
# -> 1531                             power=power)
#    1532
#    1533     # Build a Mel filter
#
# c:\users\hozrifai\desktop\junior\venv\lib\site-packages\librosa\core\spectrum.py in _spectrogram(y, S, n_fft, hop_length, power)
#    1555     else:
#    1556         # Otherwise, compute a magnitude spectrogram from input
# -> 1557         S = np.abs(stft(y, n_fft=n_fft, hop_length=hop_length))**power
#    1558
#    1559     return S, n_fft
#
# c:\users\hozrifai\desktop\junior\venv\lib\site-packages\librosa\core\spectrum.py in stft(y, n_fft, hop_length, win_length, window, center, dtype, pad_mode)
#     159
#     160     # Check audio is valid
# --> 161     util.valid_audio(y)
#     162
#     163     # Pad the time series so that frames are centered
#
# c:\users\hozrifai\desktop\junior\venv\lib\site-packages\librosa\util\utils.py in valid_audio(y, mono)
#     154
#     155     if not isinstance(y, np.ndarray):
# --> 156         raise ParameterError('data must be of type numpy.ndarray')
#     157
#     158     if not np.issubdtype(y.dtype, np.floating):
#
# ParameterError: data must be of type numpy.ndarray

# %%
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfcc, x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
